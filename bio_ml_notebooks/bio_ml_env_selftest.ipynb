# %%
import sys, os, pathlib
print("Python:", sys.executable)
print("CWD   :", os.getcwd())
print("Here? :", pathlib.Path("bio_ml_env_selftest.py").resolve().exists())
# Out:
# Python: /home/student/anaconda3/envs/bio_ml/bin/python
# CWD   : /home/student/Documents/jupyter_notebooks
# Here? : True

# %%
from bio_ml_env_selftest import run_all_tests, show_report

report = run_all_tests(
    outdir="bio_ml_env_test_out",   # relative to the notebook folder
    plots=True,                     # saves a couple of PNGs
    quick=False,                    # set True for a lighter test
    as_notebook=True
)

show_report(report)

# Optional: inspect the full dict (nicely in a Jupyter cell)
from IPython.display import JSON
JSON(report)
# Out:
# === bio_ml environment self-test ===
# Python: 3.11.14 | Env: base
# Executable: /home/student/anaconda3/envs/bio_ml/bin/python
# CWD: /home/student/Documents/jupyter_notebooks
# Packages present : biopython, ipykernel, jupyter_kernel_registry, matplotlib, matplotlib_venn, networkx, numpy, pandas, pytorch, scikit_bio, scikit_learn, scipy, seaborn, statsmodels, tensorflow
# Packages missing : (none)
# BLAS backend (hint): OPENBLAS
# Elapsed (s): 5.46
